# %%
import numpy as np
import pandas as pd

# %%
df_ny=pd.read_csv('/Users/mahmoud/Zillow_Time_Series/ny_zillow_data.csv')

# %%
df_ny.shape
# Out:
# (114, 273)

# %%
df_ny = df_ny.drop(columns=['Unnamed: 0'])

# %%
df_ny
# Out:
#      RegionID  Zipcode      City State     Metro CountyName  SizeRank  \
# 0       61807    10467  New York    NY  New York      Bronx         7
# 1       62037    11226  New York    NY  New York      Kings        11
# 2       62087    11375  New York    NY  New York     Queens        13
# 3       62045    11235  New York    NY  New York      Kings        14
# 4       61625    10011  New York    NY  New York   New York        21
# ..        ...      ...       ...   ...       ...        ...       ...
# 109     62122    11436  New York    NY  New York     Queens      8009
# 110     62078    11366  New York    NY  New York     Queens      8304
# 111     61783    10307  New York    NY  New York   Richmond      8388
# 112     62075    11363  New York    NY  New York     Queens      9912
# 113     61804    10464  New York    NY  New York      Bronx     11038
#
#       1996-04   1996-05   1996-06  ...   2017-07   2017-08   2017-09  \
# 0    152900.0  152700.0  152600.0  ...    394400    400000    407300
# 1    162000.0  162300.0  162600.0  ...    860200    851000    853900
# 2    252400.0  251800.0  251400.0  ...   1022600   1033700   1048600
# 3    190500.0  191000.0  191500.0  ...    767300    777300    788800
# 4         NaN       NaN       NaN  ...  12137600  12112600  12036600
# ..        ...       ...       ...  ...       ...       ...       ...
# 109  119000.0  119400.0  119900.0  ...    383800    382200    381000
# 110  231800.0  232000.0  232300.0  ...    830000    839100    847800
# 111  186700.0  186800.0  186900.0  ...    522000    525600    527900
# 112  295000.0  296200.0  297700.0  ...   1032000   1043700   1049800
# 113  195900.0  195600.0  195100.0  ...    513100    518200    526100
#
#       2017-10   2017-11   2017-12   2018-01   2018-02   2018-03   2018-04
# 0      411600    413200    414300    413900    411400    413200    417900
# 1      870000    885100    887800    890500    901700    930700    963200
# 2     1066400   1081200   1088800   1092700   1089500   1084000   1084600
# 3      793900    796000    799700    806600    810600    813400    816200
# 4    12050100  12016300  11946500  11978100  11849300  11563000  11478300
# ..        ...       ...       ...       ...       ...       ...       ...
# 109    382500    385600    387600    388700    390600    395100    400300
# 110    854900    859600    861700    865600    871900    882700    893600
# 111    533800    543300    550800    559300    566900    571600    575900
# 112   1047900   1041200   1035400   1040700   1048600   1052100   1051300
# 113    532000    533100    533100    534400    533300    533000    536200
#
# [114 rows x 272 columns]

# %%
# dropping Nans
df_ny = df_ny.dropna()

# %%
df_ny
# Out:
#      RegionID  Zipcode      City State     Metro CountyName  SizeRank  \
# 0       61807    10467  New York    NY  New York      Bronx         7
# 1       62037    11226  New York    NY  New York      Kings        11
# 2       62087    11375  New York    NY  New York     Queens        13
# 3       62045    11235  New York    NY  New York      Kings        14
# 5       61703    10128  New York    NY  New York   New York        22
# ..        ...      ...       ...   ...       ...        ...       ...
# 109     62122    11436  New York    NY  New York     Queens      8009
# 110     62078    11366  New York    NY  New York     Queens      8304
# 111     61783    10307  New York    NY  New York   Richmond      8388
# 112     62075    11363  New York    NY  New York     Queens      9912
# 113     61804    10464  New York    NY  New York      Bronx     11038
#
#        1996-04    1996-05    1996-06  ...  2017-07  2017-08  2017-09  2017-10  \
# 0     152900.0   152700.0   152600.0  ...   394400   400000   407300   411600
# 1     162000.0   162300.0   162600.0  ...   860200   851000   853900   870000
# 2     252400.0   251800.0   251400.0  ...  1022600  1033700  1048600  1066400
# 3     190500.0   191000.0   191500.0  ...   767300   777300   788800   793900
# 5    3676700.0  3704200.0  3729600.0  ...  7410100  7422400  7417600  7427300
# ..         ...        ...        ...  ...      ...      ...      ...      ...
# 109   119000.0   119400.0   119900.0  ...   383800   382200   381000   382500
# 110   231800.0   232000.0   232300.0  ...   830000   839100   847800   854900
# 111   186700.0   186800.0   186900.0  ...   522000   525600   527900   533800
# 112   295000.0   296200.0   297700.0  ...  1032000  1043700  1049800  1047900
# 113   195900.0   195600.0   195100.0  ...   513100   518200   526100   532000
#
#      2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0     413200   414300   413900   411400   413200   417900
# 1     885100   887800   890500   901700   930700   963200
# 2    1081200  1088800  1092700  1089500  1084000  1084600
# 3     796000   799700   806600   810600   813400   816200
# 5    7371400  7342700  7353300  7350300  7363000  7386600
# ..       ...      ...      ...      ...      ...      ...
# 109   385600   387600   388700   390600   395100   400300
# 110   859600   861700   865600   871900   882700   893600
# 111   543300   550800   559300   566900   571600   575900
# 112  1041200  1035400  1040700  1048600  1052100  1051300
# 113   533100   533100   534400   533300   533000   536200
#
# [104 rows x 272 columns]

# %%
df_ny.drop('RegionID', axis=1, inplace=True)
# Out:
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
price_columns = df_ny.columns[6:-1]  # Exclude the 'RegionID' and 'Housing_Price_Growth' columns

df_ny['Housing_Price_Growth'] = df_ny['2018-04'] - df_ny['1996-04']
# Out:
# <ipython-input-9-c70e97226b6e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ny['Housing_Price_Growth'] = df_ny['2018-04'] - df_ny['1996-04']

# %%
df_ny['Housing_Price_Growth']
# Out:
# 0       265000.0
# 1       801200.0
# 2       832200.0
# 3       625700.0
# 5      3709900.0
#          ...
# 109     281300.0
# 110     661800.0
# 111     389200.0
# 112     756300.0
# 113     340300.0
# Name: Housing_Price_Growth, Length: 104, dtype: float64

# %%
df_ny.head()
# Out:
#    Zipcode      City State     Metro CountyName  SizeRank    1996-04  \
# 0    10467  New York    NY  New York      Bronx         7   152900.0
# 1    11226  New York    NY  New York      Kings        11   162000.0
# 2    11375  New York    NY  New York     Queens        13   252400.0
# 3    11235  New York    NY  New York      Kings        14   190500.0
# 5    10128  New York    NY  New York   New York        22  3676700.0
#
#      1996-05    1996-06    1996-07  ...  2017-08  2017-09  2017-10  2017-11  \
# 0   152700.0   152600.0   152400.0  ...   400000   407300   411600   413200
# 1   162300.0   162600.0   163000.0  ...   851000   853900   870000   885100
# 2   251800.0   251400.0   251200.0  ...  1033700  1048600  1066400  1081200
# 3   191000.0   191500.0   192000.0  ...   777300   788800   793900   796000
# 5  3704200.0  3729600.0  3754600.0  ...  7422400  7417600  7427300  7371400
#
#    2017-12  2018-01  2018-02  2018-03  2018-04  Housing_Price_Growth
# 0   414300   413900   411400   413200   417900              265000.0
# 1   887800   890500   901700   930700   963200              801200.0
# 2  1088800  1092700  1089500  1084000  1084600              832200.0
# 3   799700   806600   810600   813400   816200              625700.0
# 5  7342700  7353300  7350300  7363000  7386600             3709900.0
#
# [5 rows x 272 columns]

# %%
# Identify the columns to keep as identifiers (e.g., non-date columns)
id_vars = ['Zipcode', 'City', 'State', 'Metro', 'CountyName', 'SizeRank']

# Perform the melt operation to convert to long format
df_ny_long = pd.melt(df_ny, id_vars=id_vars, var_name='Date', value_name='Housing_Price_Growth')

# Sort the DataFrame by 'Date' if desired
df_ny_long.sort_values('Date', inplace=True)
# Out:
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3417: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resultiing Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import statsmodels.api as sm

# Train-Test Split
train_data = df_ny_long[df_ny_long['Date'] < '2018-01-01']
test_data = df_ny_long[df_ny_long['Date'] >= '2018-01-01']

# Define the SARIMAX model
order = (1, 1, 1)  # (p, d, q)
seasonal_order = (1, 1, 1, 12)  # (P, D, Q, S)
model = sm.tsa.statespace.SARIMAX(train_data['Housing_Price_Growth'],
                                  order=order,
                                  seasonal_order=seasonal_order)

# Fit the SARIMAX model
model_fit = model.fit()

# Model Evaluation
predicted_values = model_fit.predict(start=test_data.index[0], end=test_data.index[-1])
mse = ((predicted_values - test_data['Housing_Price_Growth']) ** 2).mean()
rmse = np.sqrt(mse)

# Model Forecasting
forecasted_values = model_fit.forecast(steps=12)  # Example: Forecasting 12 future time periods

# Print evaluation metrics and forecasted values
print("Root Mean Squared Error (RMSE):", rmse)
print("Forecasted Values:", forecasted_values)
# Out:
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Root Mean Squared Error (RMSE): 619340.8044543021
# Forecasted Values: 27248    820384.512465
# 27249    722298.537392
# 27250    771602.449957
# 27251    821721.109095
# 27252    817768.074425
# 27253    754523.909915
# 27254    806962.904557
# 27255    848796.555044
# 27256    798789.157298
# 27257    743809.205681
# 27258    767956.085317
# 27259    838484.362296
# Name: predicted_mean, dtype: float64
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a time series plot with confidence intervals
plt.figure(figsize=(12, 6))
plt.plot(test_data['Date'], test_data['Housing_Price_Growth'], label='Actual', color='blue')
plt.plot(test_data['Date'].iloc[:len(predicted_values)], predicted_values, label='Predicted', color='orange')

# Calculate confidence intervals (assuming normally distributed errors)
std_error = np.sqrt(model_fit.params['sigma2'])
lower_bound = predicted_values - 1.96 * std_error
upper_bound = predicted_values + 1.96 * std_error

# Plot confidence intervals as shaded areas
plt.fill_between(test_data['Date'].iloc[:len(predicted_values)], lower_bound, upper_bound, alpha=0.3, color='orange')

plt.xlabel('Date')
plt.ylabel('Housing Price Growth')
plt.title('Actual vs. Predicted Housing Price Growth with Confidence Intervals')
plt.legend()
plt.show()

# %% [markdown]
# # Advanced model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Train-Test Split
train_data = df_ny_long[df_ny_long['Date'] < '2018-01-01']
test_data = df_ny_long[df_ny_long['Date'] >= '2018-01-01']

# Feature Engineering (if applicable)
# Add additional features that may impact housing price growth

# Model Configuration
order = (1, 1, 2)  # (p, d, q)
seasonal_order = (1, 1, 2, 12)  # (P, D, Q, S)

# Data Preprocessing (if necessary)
# Handle missing values, outliers, or perform data normalization

# Model Training
model = sm.tsa.statespace.SARIMAX(train_data['Housing_Price_Growth'], order=order, seasonal_order=seasonal_order)
model_fit = model.fit()

# Model Evaluation
predicted_values = model_fit.predict(start=test_data.index[0], end=test_data.index[-1])
mse = ((predicted_values - test_data['Housing_Price_Growth']) ** 2).mean()
rmse = np.sqrt(mse)

# Model Visualization
plt.figure(figsize=(12, 6))
plt.plot(test_data['Date'], test_data['Housing_Price_Growth'], label='Actual', color='blue')
plt.plot(test_data['Date'].iloc[:len(predicted_values)], predicted_values, label='Predicted', color='orange')

# Calculate confidence intervals (assuming normally distributed errors)
std_error = np.sqrt(model_fit.params['sigma2'])
lower_bound = predicted_values - 1.96 * std_error
upper_bound = predicted_values + 1.96 * std_error

# Plot confidence intervals as shaded areas
plt.fill_between(test_data['Date'].iloc[:len(predicted_values)], lower_bound, upper_bound, alpha=0.3, color='orange')

plt.xlabel('Date')
plt.ylabel('Housing Price Growth')
plt.title('Actual vs. Predicted Housing Price Growth with Confidence Intervals')
plt.legend()
plt.show()

# Print evaluation metrics
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Root Mean Squared Error (RMSE): 618827.4031815937

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Data Preparation
# Ensure data is in the correct format and free from missing values or outliers

# Feature Engineering
# Explore additional features or transformations that may enhance the model's predictive power

# Train-Test Split
train_data = df_ny_long[df_ny_long['Date'] < '2018-01-01']
test_data = df_ny_long[df_ny_long['Date'] >= '2018-01-01']

# Model Configuration
order = (1, 1, 1)  # (p, d, q)
seasonal_order = (1, 1, 1, 12)  # (P, D, Q, S)

# Data Preprocessing (if necessary)
# Handle missing values, outliers, or perform data normalization

# Model Training
model = sm.tsa.statespace.SARIMAX(train_data['Housing_Price_Growth'], order=order, seasonal_order=seasonal_order)
model_fit = model.fit()

# Model Evaluation
predicted_values = model_fit.predict(start=test_data.index[0], end=test_data.index[-1])
mse = ((predicted_values - test_data['Housing_Price_Growth']) ** 2).mean()
rmse = np.sqrt(mse)

# Model Visualization
plt.figure(figsize=(12, 6))
plt.plot(test_data['Date'], test_data['Housing_Price_Growth'], label='Actual', color='blue')
plt.plot(test_data['Date'].iloc[:len(predicted_values)], predicted_values, label='Predicted', color='orange')

# Calculate confidence intervals (assuming normally distributed errors)
std_error = np.sqrt(model_fit.params['sigma2'])
lower_bound = predicted_values - 1.96 * std_error
upper_bound = predicted_values + 1.96 * std_error

# Plot confidence intervals as shaded areas
plt.fill_between(test_data['Date'].iloc[:len(predicted_values)], lower_bound, upper_bound, alpha=0.3, color='orange')

plt.xlabel('Date')
plt.ylabel('Housing Price Growth')
plt.title('Actual vs. Predicted Housing Price Growth with Confidence Intervals')
plt.legend()
plt.show()

# Print evaluation metrics
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Root Mean Squared Error (RMSE): 619340.8044543021

# %%
# chicago_df_defl = pd.read_csv('../data/processed/chicago_june2012_to_april2018_deflated', index_col = ['Unnamed: 0'])
df_ny_train = df_ny.loc['2012-06':'2017-10',:] # 5 years 4 months for train data
df_ny_test = df_ny.loc['2017-11':'2018-04',:] # 6 months for test data

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Assuming your DataFrame is named df

# Iterate over unique zip codes
for zipcode in df_ny['Zipcode'].unique():
    # Extract the data for the current zip code
    data = df_ny.loc[df_ny['Zipcode'] == zipcode, '1996-04':'2018-04'].values[0]  # Assuming the data starts from column '1996-04' and ends at '2018-04'
    
    # Perform the ADF test
    result = adfuller(data)
    
    # Extract the p-value from the test result
    p_value = result[1]
    
    # Print the p-value and the stationarity result
    print(f"Zip Code: {zipcode}")
    print(f"ADF p-value: {p_value}")
    if p_value < 0.05:
        print("The data is stationary")
    else:
        print("The data is not stationary")
    print("------------------------------")
# Out:
# Zip Code: 10467
# ADF p-value: 0.41825013558080504
# The data is not stationary
# ------------------------------
# Zip Code: 11226
# ADF p-value: 0.9882254867110689
# The data is not stationary
# ------------------------------
# Zip Code: 11375
# ADF p-value: 0.9529539291534417
# The data is not stationary
# ------------------------------
# Zip Code: 11235
# ADF p-value: 0.8106231633355598
# The data is not stationary
# ------------------------------
# Zip Code: 10128
# ADF p-value: 0.9292613391446272
# The data is not stationary
# ------------------------------
# Zip Code: 10462
# ADF p-value: 0.5014042101263257
# The data is not stationary
# ------------------------------
# Zip Code: 10463
# ADF p-value: 0.9077529714301922
# The data is not stationary
# ------------------------------
# Zip Code: 11230
# ADF p-value: 0.973554814904793
# The data is not stationary
# ------------------------------
# Zip Code: 11209
# ADF p-value: 0.7044771402246052
# The data is not stationary
# ------------------------------
# Zip Code: 11212
# ADF p-value: 0.8003414457926936
# The data is not stationary
# ------------------------------
# Zip Code: 11214
# ADF p-value: 0.9582876275232711
# The data is not stationary
# ------------------------------
# Zip Code: 11221
# ADF p-value: 0.9870518450373295
# The data is not stationary
# ------------------------------
# Zip Code: 11229
# ADF p-value: 0.8104079554432361
# The data is not stationary
# ------------------------------
# Zip Code: 11377
# ADF p-value: 0.715989939010262
# The data is not stationary
# ------------------------------
# Zip Code: 11234
# ADF p-value: 0.655809550952476
# The data is not stationary
# ------------------------------
# Zip Code: 11355
# ADF p-value: 0.87008812164468
# The data is not stationary
# ------------------------------
# Zip Code: 10314
# ADF p-value: 0.6458487875695844
# The data is not stationary
# ------------------------------
# Zip Code: 11215
# ADF p-value: 0.9837573347851635
# The data is not stationary
# ------------------------------
# Zip Code: 11211
# ADF p-value: 0.9986576909330424
# The data is not stationary
# ------------------------------
# Zip Code: 11385
# ADF p-value: 0.8368725122123453
# The data is not stationary
# ------------------------------
# Zip Code: 11373
# ADF p-value: 0.7462416299899356
# The data is not stationary
# ------------------------------
# Zip Code: 11233
# ADF p-value: 0.9333356806334993
# The data is not stationary
# ------------------------------
# Zip Code: 11236
# ADF p-value: 0.65073080593905
# The data is not stationary
# ------------------------------
# Zip Code: 11372
# ADF p-value: 0.5983293795211403
# The data is not stationary
# ------------------------------
# Zip Code: 11218
# ADF p-value: 0.9092250762233853
# The data is not stationary
# ------------------------------
# Zip Code: 11223
# ADF p-value: 0.9770463485154256
# The data is not stationary
# ------------------------------
# Zip Code: 11208
# ADF p-value: 0.7932985227706215
# The data is not stationary
# ------------------------------
# Zip Code: 11204
# ADF p-value: 0.886952072801483
# The data is not stationary
# ------------------------------
# Zip Code: 11219
# ADF p-value: 0.9717742129574534
# The data is not stationary
# ------------------------------
# Zip Code: 11368
# ADF p-value: 0.6678037425449955
# The data is not stationary
# ------------------------------
# Zip Code: 11203
# ADF p-value: 0.8147202202490094
# The data is not stationary
# ------------------------------
# Zip Code: 11220
# ADF p-value: 0.9170087812952284
# The data is not stationary
# ------------------------------
# Zip Code: 11216
# ADF p-value: 0.9724380332622611
# The data is not stationary
# ------------------------------
# Zip Code: 11354
# ADF p-value: 0.8674454067466726
# The data is not stationary
# ------------------------------
# Zip Code: 10466
# ADF p-value: 0.5502695353799942
# The data is not stationary
# ------------------------------
# Zip Code: 11374
# ADF p-value: 0.7784035813844356
# The data is not stationary
# ------------------------------
# Zip Code: 10473
# ADF p-value: 0.5508424728083047
# The data is not stationary
# ------------------------------
# Zip Code: 11210
# ADF p-value: 0.890979192712693
# The data is not stationary
# ------------------------------
# Zip Code: 11434
# ADF p-value: 0.314384651980057
# The data is not stationary
# ------------------------------
# Zip Code: 11224
# ADF p-value: 0.9367812281977039
# The data is not stationary
# ------------------------------
# Zip Code: 10306
# ADF p-value: 0.710613136373946
# The data is not stationary
# ------------------------------
# Zip Code: 11691
# ADF p-value: 0.56310698761562
# The data is not stationary
# ------------------------------
# Zip Code: 10469
# ADF p-value: 0.4297372414214835
# The data is not stationary
# ------------------------------
# Zip Code: 10312
# ADF p-value: 0.7016310455030077
# The data is not stationary
# ------------------------------
# Zip Code: 10461
# ADF p-value: 0.21580520814807436
# The data is not stationary
# ------------------------------
# Zip Code: 11106
# ADF p-value: 0.9864786835168864
# The data is not stationary
# ------------------------------
# Zip Code: 11432
# ADF p-value: 0.6331554932372636
# The data is not stationary
# ------------------------------
# Zip Code: 11222
# ADF p-value: 0.9945168916750926
# The data is not stationary
# ------------------------------
# Zip Code: 11435
# ADF p-value: 0.4000065488735691
# The data is not stationary
# ------------------------------
# Zip Code: 11365
# ADF p-value: 0.7783478134471209
# The data is not stationary
# ------------------------------
# Zip Code: 11103
# ADF p-value: 0.8433837098083901
# The data is not stationary
# ------------------------------
# Zip Code: 11367
# ADF p-value: 0.8356778839755006
# The data is not stationary
# ------------------------------
# Zip Code: 11102
# ADF p-value: 0.9914507211299143
# The data is not stationary
# ------------------------------
# Zip Code: 10304
# ADF p-value: 0.6883707000863915
# The data is not stationary
# ------------------------------
# Zip Code: 10301
# ADF p-value: 0.6087715479179516
# The data is not stationary
# ------------------------------
# Zip Code: 11357
# ADF p-value: 0.7418383999578915
# The data is not stationary
# ------------------------------
# Zip Code: 10305
# ADF p-value: 0.5883898050284532
# The data is not stationary
# ------------------------------
# Zip Code: 11105
# ADF p-value: 0.9386646817454476
# The data is not stationary
# ------------------------------
# Zip Code: 10465
# ADF p-value: 0.519571873156868
# The data is not stationary
# ------------------------------
# Zip Code: 11364
# ADF p-value: 0.5917200988077866
# The data is not stationary
# ------------------------------
# Zip Code: 11358
# ADF p-value: 0.7166610209856102
# The data is not stationary
# ------------------------------
# Zip Code: 11104
# ADF p-value: 0.6481464619936924
# The data is not stationary
# ------------------------------
# Zip Code: 11228
# ADF p-value: 0.7523362900583366
# The data is not stationary
# ------------------------------
# Zip Code: 11379
# ADF p-value: 0.7959002476791347
# The data is not stationary
# ------------------------------
# Zip Code: 11413
# ADF p-value: 0.2723453400395307
# The data is not stationary
# ------------------------------
# Zip Code: 11420
# ADF p-value: 0.250562124638782
# The data is not stationary
# ------------------------------
# Zip Code: 11414
# ADF p-value: 0.242430434704012
# The data is not stationary
# ------------------------------
# Zip Code: 10309
# ADF p-value: 0.5584228654865655
# The data is not stationary
# ------------------------------
# Zip Code: 11361
# ADF p-value: 0.642796748081996
# The data is not stationary
# ------------------------------
# Zip Code: 11412
# ADF p-value: 0.3827661470173447
# The data is not stationary
# ------------------------------
# Zip Code: 10471
# ADF p-value: 0.5274648526188473
# The data is not stationary
# ------------------------------
# Zip Code: 11378
# ADF p-value: 0.7131747949291574
# The data is not stationary
# ------------------------------
# Zip Code: 11421
# ADF p-value: 0.703212893122385
# The data is not stationary
# ------------------------------
# Zip Code: 11419
# ADF p-value: 0.44517418210057347
# The data is not stationary
# ------------------------------
# Zip Code: 11433
# ADF p-value: 0.4250141270367888
# The data is not stationary
# ------------------------------
# Zip Code: 11360
# ADF p-value: 0.7529983749340861
# The data is not stationary
# ------------------------------
# Zip Code: 10308
# ADF p-value: 0.6721494435898174
# The data is not stationary
# ------------------------------
# Zip Code: 11415
# ADF p-value: 0.8728054695686964
# The data is not stationary
# ------------------------------
# Zip Code: 11418
# ADF p-value: 0.632399652691264
# The data is not stationary
# ------------------------------
# Zip Code: 11423
# ADF p-value: 0.6315495598431651
# The data is not stationary
# ------------------------------
# Zip Code: 11369
# ADF p-value: 0.7007416599736562
# The data is not stationary
# ------------------------------
# Zip Code: 10310
# ADF p-value: 0.7571182401637967
# The data is not stationary
# ------------------------------
# Zip Code: 10303
# ADF p-value: 0.6370590450139204
# The data is not stationary
# ------------------------------
# Zip Code: 11422
# ADF p-value: 0.4486093077313592
# The data is not stationary
# ------------------------------
# Zip Code: 11694
# ADF p-value: 0.3315507270744803
# The data is not stationary
# ------------------------------
# Zip Code: 11417
# ADF p-value: 0.6361028645454544
# The data is not stationary
# ------------------------------
# Zip Code: 11427
# ADF p-value: 0.522055902364728
# The data is not stationary
# ------------------------------
# Zip Code: 11692
# ADF p-value: 0.5758509315545253
# The data is not stationary
# ------------------------------
# Zip Code: 11370
# ADF p-value: 0.7440976238845238
# The data is not stationary
# ------------------------------
# Zip Code: 11356
# ADF p-value: 0.8372013767848859
# The data is not stationary
# ------------------------------
# Zip Code: 11429
# ADF p-value: 0.49231882102236035
# The data is not stationary
# ------------------------------
# Zip Code: 11362
# ADF p-value: 0.7845199540485241
# The data is not stationary
# ------------------------------
# Zip Code: 11411
# ADF p-value: 0.3646546986334896
# The data is not stationary
# ------------------------------
# Zip Code: 10470
# ADF p-value: 0.41418399047895843
# The data is not stationary
# ------------------------------
# Zip Code: 11426
# ADF p-value: 0.4686594571102851
# The data is not stationary
# ------------------------------
# Zip Code: 10302
# ADF p-value: 0.29399068635807707
# The data is not stationary
# ------------------------------
# Zip Code: 11428
# ADF p-value: 0.5669523303423151
# The data is not stationary
# ------------------------------
# Zip Code: 11004
# ADF p-value: 0.5225295826872246
# The data is not stationary
# ------------------------------
# Zip Code: 11416
# ADF p-value: 0.5734579791360198
# The data is not stationary
# ------------------------------
# Zip Code: 11436
# ADF p-value: 0.4447831919443719
# The data is not stationary
# ------------------------------
# Zip Code: 11366
# ADF p-value: 0.8263832363689527
# The data is not stationary
# ------------------------------
# Zip Code: 10307
# ADF p-value: 0.6139393386253785
# The data is not stationary
# ------------------------------
# Zip Code: 11363
# ADF p-value: 0.47772566474737277
# The data is not stationary
# ------------------------------
# Zip Code: 10464
# ADF p-value: 0.28551084139939525
# The data is not stationary
# ------------------------------

# %%
df_ny.loc[:, 'Housing_Price_Growth'] = pd.to_numeric(df_ny['Housing_Price_Growth'], errors='coerce')

# %%
df_ny.loc[:, 'Stationary_Housing_Price_Growth'] = df_ny['Housing_Price_Growth'].diff()
df_ny.loc[:, 'Stationary_Housing_Price_Growth'] = df_ny['Stationary_Housing_Price_Growth'].fillna(0)

# %%
result = adfuller(df_ny['Stationary_Housing_Price_Growth'])
print("ADF Statistic:", result[0])
print("p-value:", result[1])
# Out:
# ADF Statistic: -7.446824591262719
# p-value: 5.808723064272669e-11

# %%
from statsmodels.tsa.stattools import adfuller

# Perform the ADF test
result = adfuller(df_ny['Stationary_Housing_Price_Growth'])
print("ADF Statistic:", result[0])
print("p-value:", result[1])

# Interpret the results
if result[1] < 0.05:
    print("The stationary housing price growth is stationary (reject the null hypothesis).")
else:
    print("The stationary housing price growth is non-stationary (fail to reject the null hypothesis).")
# Out:
# ADF Statistic: -7.446824591262719
# p-value: 5.808723064272669e-11
# The stationary housing price growth is stationary (reject the null hypothesis).

# %%
import seaborn as sns

# Create a DataFrame for visualization
vis_df = pd.DataFrame({'Date': test_data['Date'], 'Actual': test_data['Housing_Price_Growth'], 'Predicted': predicted_values})

# Set the figure size
plt.figure(figsize=(10, 6))

# Plot the actual and predicted values
sns.lineplot(data=vis_df, x='Date', y='Actual', label='Actual')
sns.lineplot(data=vis_df, x='Date', y='Predicted', label='Predicted')

# Set plot title and labels
plt.title('Actual vs Predicted Housing Prices')
plt.xlabel('Date')
plt.ylabel('Housing Price')

# Display the plot
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_ny
# Out:
#      Zipcode      City State     Metro CountyName  SizeRank    1996-04  \
# 0      10467  New York    NY  New York      Bronx         7   152900.0
# 1      11226  New York    NY  New York      Kings        11   162000.0
# 2      11375  New York    NY  New York     Queens        13   252400.0
# 3      11235  New York    NY  New York      Kings        14   190500.0
# 5      10128  New York    NY  New York   New York        22  3676700.0
# ..       ...       ...   ...       ...        ...       ...        ...
# 109    11436  New York    NY  New York     Queens      8009   119000.0
# 110    11366  New York    NY  New York     Queens      8304   231800.0
# 111    10307  New York    NY  New York   Richmond      8388   186700.0
# 112    11363  New York    NY  New York     Queens      9912   295000.0
# 113    10464  New York    NY  New York      Bronx     11038   195900.0
#
#        1996-05    1996-06    1996-07  ...  2017-08  2017-09  2017-10  2017-11  \
# 0     152700.0   152600.0   152400.0  ...   400000   407300   411600   413200
# 1     162300.0   162600.0   163000.0  ...   851000   853900   870000   885100
# 2     251800.0   251400.0   251200.0  ...  1033700  1048600  1066400  1081200
# 3     191000.0   191500.0   192000.0  ...   777300   788800   793900   796000
# 5    3704200.0  3729600.0  3754600.0  ...  7422400  7417600  7427300  7371400
# ..         ...        ...        ...  ...      ...      ...      ...      ...
# 109   119400.0   119900.0   120500.0  ...   382200   381000   382500   385600
# 110   232000.0   232300.0   232800.0  ...   839100   847800   854900   859600
# 111   186800.0   186900.0   187100.0  ...   525600   527900   533800   543300
# 112   296200.0   297700.0   299400.0  ...  1043700  1049800  1047900  1041200
# 113   195600.0   195100.0   194400.0  ...   518200   526100   532000   533100
#
#      2017-12  2018-01  2018-02  2018-03  2018-04  Housing_Price_Growth
# 0     414300   413900   411400   413200   417900              265000.0
# 1     887800   890500   901700   930700   963200              801200.0
# 2    1088800  1092700  1089500  1084000  1084600              832200.0
# 3     799700   806600   810600   813400   816200              625700.0
# 5    7342700  7353300  7350300  7363000  7386600             3709900.0
# ..       ...      ...      ...      ...      ...                   ...
# 109   387600   388700   390600   395100   400300              281300.0
# 110   861700   865600   871900   882700   893600              661800.0
# 111   550800   559300   566900   571600   575900              389200.0
# 112  1035400  1040700  1048600  1052100  1051300              756300.0
# 113   533100   534400   533300   533000   536200              340300.0
#
# [104 rows x 272 columns]

# %%
import numpy as np

# Calculate z-scores for the 'Housing_Price' column
z_scores = (df_ny['Housing_Price_Growth'] - df_ny['Housing_Price_Growth'].mean()) / df_ny['Housing_Price_Growth'].std()

# Set a threshold for identifying outliers (e.g., z-score greater than 3)
threshold = 3

# Create a mask to identify outliers
outlier_mask = np.abs(z_scores) > threshold

# Remove outliers from the dataset
df_ny_no_outliers = df_ny[~outlier_mask]

# %%
import matplotlib.pyplot as plt

# Sort the DataFrame by SizeRank
filtered_data = df_ny[df_ny['SizeRank'] == 7]

# Extract the relevant columns for plotting
dates = filtered_data.columns[6:-1]  # Assuming the price columns start from index 6
prices = filtered_data.iloc[0, 6:-1].values

# Plot the price change over time for the selected row
plt.figure(figsize=(12, 6))
plt.plot(dates, prices)

plt.xlabel('Date')
plt.ylabel('Housing Price')
plt.title('Housing Price Change Over Time (SizeRank = 7)')
plt.show()

# %% [markdown]
# # LSTM Model
# - everytime i run it dies so i deleted it

# %% [markdown]
# # VAR Model

# %%
# Filter out non-date values from 'ds' column
date_mask = pd.to_datetime(df['ds'], errors='coerce').notnull()
df_filtered = df[date_mask]

# Convert 'ds' column to datetime format
df_filtered['ds'] = pd.to_datetime(df_filtered['ds'], format='%Y-%m-%d')
# Out:
# <ipython-input-136-fdbf23f4c75a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['ds'] = pd.to_datetime(df_filtered['ds'], format='%Y-%m-%d')

# %%
from statsmodels.tsa.vector_ar.var_model import VAR

# Remove non-numeric columns from train_data
train_data_numeric = train_data.select_dtypes(include=[np.number])

# Model Training
model = VAR(train_data_numeric)
model_fit = model.fit()

# Forecasting
lag_order = model_fit.k_ar
predicted_values = model_fit.forecast(train_data_numeric.values[-lag_order:], len(test_data))

# Model Evaluation
mse = ((predicted_values[:, 0] - test_data['Housing_Price_Growth']) ** 2).mean()
rmse = np.sqrt(mse)

# Model Visualization
plt.figure(figsize=(12, 6))
plt.plot(test_data.index, test_data['Housing_Price_Growth'], label='Actual', color='blue')
plt.plot(test_data.index, predicted_values[:, 0], label='Predicted', color='orange')
plt.xlabel('Date')
plt.ylabel('Housing Price Growth')
plt.title('Actual vs. Predicted Housing Price Growth (VAR Model)')
plt.legend()
plt.show()

# Print evaluation metrics
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# /Users/mahmoud/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Root Mean Squared Error (RMSE): 716653.5547507725

# %%
ny_dict.keys()
# Out:
# dict_keys(['10467', '11226', '11375', '11235', '10128', '10462', '10463', '11230', '11209', '11212', '11214', '11221', '11229', '11377', '11234', '11355', '10314', '11215', '11211', '11385', '11373', '11233', '11236', '11372', '11218', '11223', '11208', '11204', '11219', '11368', '11203', '11220', '11216', '11354', '10466', '11374', '10473', '11210', '11434', '11224', '10306', '11691', '10469', '10312', '10461', '11106', '11432', '11222', '11435', '11365', '11103', '11367', '11102', '10304', '10301', '11357', '10305', '11105', '10465', '11364', '11358', '11104', '11228', '11379', '11413', '11420', '11414', '10309', '11361', '11412', '10471', '11378', '11421', '11419', '11433', '11360', '10308', '11415', '11418', '11423', '11369', '10310', '10303', '11422', '11694', '11417', '11427', '11692', '11370', '11356', '11429', '11362', '11411', '10470', '11426', '10302', '11428', '11004', '11416', '11436', '11366', '10307', '11363', '10464'])

# %%
print('The data covers {} months.'.format(len(ny_dict['11211'])))
# Out:
# The data covers 265 months.

# %% [markdown]
# # Arima model does not work here since i have non numeric columns.

# %%
train_data = df_ny.loc['1996-04':'2018-04']
test_data = df_ny.loc['2012-01':]

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# Create and fit the ARIMA model
model = ARIMA(train_data, order=(1, 1, 2))
model_fit = model.fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-3db4450530f6> in <module>
#       1 # Create and fit the ARIMA model
# ----> 2 model = ARIMA(train_data, order=(1, 1, 2))
#       3 model_fit = model.fit()
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/arima/model.py in __init__(self, endog, exog, order, seasonal_order, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     156         # this criteria. Instead, we'll just make sure that the parameter
#     157         # estimates from those methods satisfy the criteria.)
# --> 158         self._spec_arima = SARIMAXSpecification(
#     159             endog, exog=exog, order=order, seasonal_order=seasonal_order,
#     160             trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/arima/specification.py in __init__(self, endog, exog, order, seasonal_order, ar_order, diff, ma_order, seasonal_ar_order, seasonal_diff, seasonal_ma_order, seasonal_periods, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     444         # especially validating shapes, retrieving names, and potentially
#     445         # providing us with a time series index
# --> 446         self._model = TimeSeriesModel(endog, exog=exog, dates=dates, freq=freq,
#     447                                       missing=missing)
#     448         self.endog = None if faux_endog else self._model.endog
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in __init__(self, endog, exog, dates, freq, missing, **kwargs)
#     468         self, endog, exog=None, dates=None, freq=None, missing="none", **kwargs
#     469     ):
# --> 470         super().__init__(endog, exog, missing=missing, **kwargs)
#     471
#     472         # Date handling in indexes
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     268
#     269     def __init__(self, endog, exog=None, **kwargs):
# --> 270         super().__init__(endog, exog, **kwargs)
#     271         self.initialize()
#     272
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      93         missing = kwargs.pop('missing', 'none')
#      94         hasconst = kwargs.pop('hasconst', None)
# ---> 95         self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                                       **kwargs)
#      97         self.k_constant = self.data.k_constant
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     133
#     134     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136         # kwargs arrays could have changed, easier to just attach here
#     137         for key in kwargs:
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     673
#     674     klass = handle_data_class_factory(endog, exog)
# --> 675     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676                  **kwargs)
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      82             self.orig_endog = endog
#      83             self.orig_exog = exog
# ---> 84             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      85
#      86         self.const_idx = None
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/data.py in _convert_endog_exog(self, endog, exog)
#     507         exog = exog if exog is None else np.asarray(exog)
#     508         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 509             raise ValueError("Pandas data cast to numpy dtype of object. "
#     510                              "Check input data with np.asarray(data).")
#     511         return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %%
df_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104 entries, 0 to 113
# Columns: 272 entries, RegionID to 2018-04
# dtypes: float64(219), int64(49), object(4)
# memory usage: 226.8+ KB

# %%
non_numeric_columns = df_ny.select_dtypes(exclude=['float64', 'int64']).columns
print(non_numeric_columns)
# Out:
# Index(['City', 'State', 'Metro', 'CountyName'], dtype='object')

# %% [markdown]
# # So I will do a SARIMAX model

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
train_data = df_ny.loc['1996-04':'2018-04']
test_data = df_ny.loc['2012-01':]

# %%
# Convert the time period columns to datetime format
date_columns = df_ny.columns[7:]  # Assuming the date columns start from index 7
df_ny[date_columns] = df_ny[date_columns].apply(pd.to_datetime, format='%Y-%m')

# Set the index column (e.g., RegionID, Zipcode) if appropriate
# df_ny.set_index('RegionID', inplace=True)

# Convert the housing price data to numeric format
df_ny = df_ny.apply(pd.to_numeric, errors='coerce')

# %%
target_variable = '2018-04'  # Replace with the desired target variable column name

exogenous_variables = ['SizeRank']  # Replace with the desired exogenous variable column names

# %%
train_data = df_ny.loc[:, :'2017-12']
test_data = df_ny.loc[:, '2018-01':]

# %%
# Define the order and seasonal order for the SARIMAX model
order = (1, 1, 1)
seasonal_order = (1, 1, 1, 12)

model = SARIMAX(train_data[target_variable], exog=train_data[exogenous_variables], order=order, seasonal_order=seasonal_order)
model_fit = model.fit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2018-04'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-e2f5aed5be48> in <module>
#       3 seasonal_order = (1, 1, 1, 12)
#       4
# ----> 5 model = SARIMAX(train_data[target_variable], exog=train_data[exogenous_variables], order=order, seasonal_order=seasonal_order)
#       6 model_fit = model.fit()
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: '2018-04'

# %%
# Train size is 6 years and 10 months (82 months), test size is 6 months
from sklearn.model_selection import train_test_split

train, test = train_test_split(ny_dict['11211'], train_size=200)

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
ny_dict['11211'] = pd.to_numeric(ny_dict['11211'], errors='coerce')

# %%
model = ARIMA(train, order=(1, 1, 2))
model_fit = model.fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-da263f39da60> in <module>
# ----> 1 model = ARIMA(train, order=(1, 1, 2))
#       2 model_fit = model.fit()
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/arima/model.py in __init__(self, endog, exog, order, seasonal_order, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     156         # this criteria. Instead, we'll just make sure that the parameter
#     157         # estimates from those methods satisfy the criteria.)
# --> 158         self._spec_arima = SARIMAXSpecification(
#     159             endog, exog=exog, order=order, seasonal_order=seasonal_order,
#     160             trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/arima/specification.py in __init__(self, endog, exog, order, seasonal_order, ar_order, diff, ma_order, seasonal_ar_order, seasonal_diff, seasonal_ma_order, seasonal_periods, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     444         # especially validating shapes, retrieving names, and potentially
#     445         # providing us with a time series index
# --> 446         self._model = TimeSeriesModel(endog, exog=exog, dates=dates, freq=freq,
#     447                                       missing=missing)
#     448         self.endog = None if faux_endog else self._model.endog
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in __init__(self, endog, exog, dates, freq, missing, **kwargs)
#     468         self, endog, exog=None, dates=None, freq=None, missing="none", **kwargs
#     469     ):
# --> 470         super().__init__(endog, exog, missing=missing, **kwargs)
#     471
#     472         # Date handling in indexes
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     268
#     269     def __init__(self, endog, exog=None, **kwargs):
# --> 270         super().__init__(endog, exog, **kwargs)
#     271         self.initialize()
#     272
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      93         missing = kwargs.pop('missing', 'none')
#      94         hasconst = kwargs.pop('hasconst', None)
# ---> 95         self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                                       **kwargs)
#      97         self.k_constant = self.data.k_constant
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     133
#     134     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136         # kwargs arrays could have changed, easier to just attach here
#     137         for key in kwargs:
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     673
#     674     klass = handle_data_class_factory(endog, exog)
# --> 675     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676                  **kwargs)
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      82             self.orig_endog = endog
#      83             self.orig_exog = exog
# ---> 84             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      85
#      86         self.const_idx = None
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/data.py in _convert_endog_exog(self, endog, exog)
#     507         exog = exog if exog is None else np.asarray(exog)
#     508         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 509             raise ValueError("Pandas data cast to numpy dtype of object. "
#     510                              "Check input data with np.asarray(data).")
#     511         return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
