# %%
import pandas as pd
df = pd.read_csv('/Users/mahmoud/Zillow_Time_Series/zillow_dataaa.csv.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-bff0037f44eb> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('/Users/mahmoud/Zillow_Time_Series/zillow_dataaa.csv.csv')
#
# ...

# %%
df
# Out:
#      Zipcode      City State     Metro CountyName  SizeRank   1996-04  \
# 0      10467  New York    NY  New York      Bronx         7  152900.0
# 1      11226  New York    NY  New York      Kings        11  162000.0
# 2      11375  New York    NY  New York     Queens        13  252400.0
# 3      11235  New York    NY  New York      Kings        14  190500.0
# 4      10011  New York    NY  New York   New York        21       NaN
# ..       ...       ...   ...       ...        ...       ...       ...
# 109    11436  New York    NY  New York     Queens      8009  119000.0
# 110    11366  New York    NY  New York     Queens      8304  231800.0
# 111    10307  New York    NY  New York   Richmond      8388  186700.0
# 112    11363  New York    NY  New York     Queens      9912  295000.0
# 113    10464  New York    NY  New York      Bronx     11038  195900.0
#
#       1996-05   1996-06   1996-07  ...   2017-07   2017-08   2017-09  \
# ...

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df= df.drop(columns=['RegionID'])

# %%
df.head()
# Out:
#    Zipcode      City State     Metro CountyName  SizeRank   1996-04   1996-05  \
# 0    10467  New York    NY  New York      Bronx         7  152900.0  152700.0
# 1    11226  New York    NY  New York      Kings        11  162000.0  162300.0
# 2    11375  New York    NY  New York     Queens        13  252400.0  251800.0
# 3    11235  New York    NY  New York      Kings        14  190500.0  191000.0
# 4    10011  New York    NY  New York   New York        21       NaN       NaN
#
#     1996-06   1996-07  ...   2017-07   2017-08   2017-09   2017-10   2017-11  \
# 0  152600.0  152400.0  ...    394400    400000    407300    411600    413200
# 1  162600.0  163000.0  ...    860200    851000    853900    870000    885100
# 2  251400.0  251200.0  ...   1022600   1033700   1048600   1066400   1081200
# 3  191500.0  192000.0  ...    767300    777300    788800    793900    796000
# 4       NaN       NaN  ...  12137600  12112600  12036600  12050100  12016300
#
# ...

# %%
df.shape
# Out:
# (114, 271)
